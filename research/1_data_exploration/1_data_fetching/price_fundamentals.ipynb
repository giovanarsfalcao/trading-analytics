# %%
import yfinance as yf
from utils import yfinance_fix

TICKER = "AAPL"
PERIOD = "730d" if INTERVAL == "1D" else "max"

# Step 1: Fetch historical price data for a ticker

def fetch_price_data(ticker = TICKER, interval = INTERVAL, period = PERIOD):
    df = yf.download(ticker, session=yfinance_fix.chrome_session, interval = interval, period = period)
    return df

df

# %%
# Step 2: Fetch fundamental data for a ticker

def fetch_fundamental_data(ticker):

# %%
# Step 3: Fetch Benchmark data

# %%
# Step 4: Fetch alternative data for stocks in the same sector or industry

def fetch_fundamental_data(ticker):
